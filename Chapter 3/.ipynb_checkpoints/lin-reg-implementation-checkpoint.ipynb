# %%
# %matplotlib inline
import torch
from d2l import torch as d2l
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 import torch
# ----> 3 from d2l import torch as d2l
#       4 get_ipython().system('conda activate d2l')
#
# ModuleNotFoundError: No module named 'd2l'

# %%
class LinearRegression(d2l):
    """Linear Regression Model"""
    def __init__(self, num_inputs, lr, sigma=0.01):
        super().__init__()
        self.save_hyperparameters()
        self.w = torch.normal(0, sigma, (num_inputs, 1), requires_grad = True) #initliaze weights
        self.b = torch.zeros(1, requires_grad = True) #initiialize bias
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 class LinearRegression(d2l):
#       2     """Linear Regression Model"""
#       3     def __init__(self, num_inputs, lr, sigma=0.01):
#
# NameError: name 'd2l' is not defined

# %%
@d2l.add_to_class(LinearRegression)
def forward(self, X):
    return torch.matmul(X, self.w) + self.b #compute the y_hat = Xw + b function for every row of X
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 @d2l.add_to_class(LinearRegression)
#       2 def forward(self, X):
#       3     return torch.matmul(X, self.w) + self.b
#
# NameError: name 'd2l' is not defined

# %%
@d2l.add_to_class(LinearRegression)
def loss(self, y_hat ,
