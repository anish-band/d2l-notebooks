# %%
num_tosses = 100
heads = sum([random.random() > 0.5 for _ in range(num_tosses)]) #float between 0 and 1 > 0.5 makes it true or false
tails = num_tosses - heads
print("heads, tails: ", [heads, tails])
